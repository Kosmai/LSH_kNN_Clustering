# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from keras.models import Sequential
from keras.layers import Input, Dense, Conv1D, MaxPooling1D, UpSampling1D, BatchNormalization, LSTM, RepeatVector
from keras.models import Model
from keras import regularizers
from datetime import datetime
import time
import pandas as pd

# %%
data = pd.read_csv('nasdaq2007_17.csv', sep = '\t', header=None, index_col = 0)
data.index.name = None
data
# Out:
#          1        2        3        4     ...    3647    3648    3649    3650
# a     11.1440  10.4710  10.8280  10.6980  ...   68.25   68.11   67.47   66.81
# aa    47.4580  45.8700  46.2490  47.8520  ...   46.97   45.89   43.33   43.01
# aaba  13.8800  12.9700  13.2900  13.0900  ...   72.22   71.16   70.19   70.56
# aapl   1.2037   1.1589   1.1385   1.1437  ...  174.18  175.61  175.25  174.67
# abc   13.9910  13.4340  13.1950  13.4150  ...   74.91   75.01   75.27   75.00
# ...       ...      ...      ...      ...  ...     ...     ...     ...     ...
# xray  17.2850  16.9010  17.0160  17.4210  ...   64.38   64.52   65.56   65.58
# xrx   36.3880  35.2030  35.7070  35.1040  ...   28.59   29.37   29.27   29.17
# yum    8.2660   8.3172   8.2781   8.3591  ...   81.01   81.13   79.53   79.59
# zbh   46.3950  45.8150  42.1810  41.5820  ...  108.72  109.17  111.84  110.75
# zion  47.6690  46.6680  46.5700  46.9740  ...   44.88   44.55   43.97   43.93
#
# [359 rows x 3650 columns]

# %%
def get_time_series(data, index):
  ts = pd.DataFrame()
  ts ['value'] = data.iloc[[index]].transpose().iloc[:,0]
  ts['date'] = pd.date_range('2007-01-01', periods=ts.shape[0]).tolist()
  ts = ts.set_index('date')
  return ts

# %%
ts = get_time_series(data, 0)
plt.figure(figsize=(16, 8))
plt.style.use('fivethirtyeight')
plt.plot(ts['value'])
plt.xlabel('Date')
plt.ylabel('Value')
plt.show()

# %%
window_size = 10

training_ratio = 0.7
training_size = int(training_ratio * ts.shape[0])

scaler = MinMaxScaler()

x_train = []
for i in range(window_size + 1,len(ts['value'])):
  x_train.append(scaler.fit_transform(ts['value'].values[i-window_size:i].reshape(-1, 1)))

x_train = np.array(x_train)

x_test = x_train[training_size:].astype('float32')
x_train = x_train[:training_size].astype('float32')

# %% [markdown]
# # TRAINING

# %%
encoding_dim = 3
epochs = 100

input_window = Input(shape=(window_size,1))
x = Conv1D(16, 3, activation="relu", padding="same")(input_window) # 10 dims
#x = BatchNormalization()(x)
x = MaxPooling1D(2, padding="same")(x) # 5 dims
x = Conv1D(1, 3, activation="relu", padding="same")(x) # 5 dims
#x = BatchNormalization()(x)
encoded = MaxPooling1D(2, padding="same")(x) # 3 dims

encoder = Model(input_window, encoded)

# 3 dimensions in the encoded layer

x = Conv1D(1, 3, activation="relu", padding="same")(encoded) # 3 dims
#x = BatchNormalization()(x)
x = UpSampling1D(2)(x) # 6 dims
x = Conv1D(16, 2, activation='relu')(x) # 5 dims
#x = BatchNormalization()(x)
x = UpSampling1D(2)(x) # 10 dims
decoded = Conv1D(1, 3, activation='sigmoid', padding='same')(x) # 10 dims
autoencoder = Model(input_window, decoded)
autoencoder.summary()

autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
history = autoencoder.fit(x_train, x_train,
                epochs=epochs,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test, x_test))

decoded_stocks = autoencoder.predict(x_test)
# Out:
# Model: "model_37"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_19 (InputLayer)       [(None, 10, 1)]           0
#
#  conv1d_90 (Conv1D)          (None, 10, 16)            64
#
#  max_pooling1d_36 (MaxPoolin  (None, 5, 16)            0
#  g1D)
#
#  conv1d_91 (Conv1D)          (None, 5, 1)              49
#
#  max_pooling1d_37 (MaxPoolin  (None, 3, 1)             0
#  g1D)
#
#  conv1d_92 (Conv1D)          (None, 3, 1)              4
#
#  up_sampling1d_36 (UpSamplin  (None, 6, 1)             0
#  g1D)
#
#  conv1d_93 (Conv1D)          (None, 5, 16)             48
#
#  up_sampling1d_37 (UpSamplin  (None, 10, 16)           0
#  g1D)
#
#  conv1d_94 (Conv1D)          (None, 10, 1)             49
#
# =================================================================
# Total params: 214
# Trainable params: 214
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 3/3 [==============================] - 1s 98ms/step - loss: 0.6970 - val_loss: 0.6964
# Epoch 2/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6957 - val_loss: 0.6953
# Epoch 3/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6949 - val_loss: 0.6945
# Epoch 4/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6942 - val_loss: 0.6938
# Epoch 5/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6938 - val_loss: 0.6934
# Epoch 6/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6934 - val_loss: 0.6930
# Epoch 7/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6931 - val_loss: 0.6927
# Epoch 8/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6929 - val_loss: 0.6926
# Epoch 9/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6928 - val_loss: 0.6926
# Epoch 10/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6928 - val_loss: 0.6925
# Epoch 11/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6927 - val_loss: 0.6923
# Epoch 12/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6926 - val_loss: 0.6921
# Epoch 13/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6924 - val_loss: 0.6920
# Epoch 14/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6923 - val_loss: 0.6919
# Epoch 15/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6922 - val_loss: 0.6917
# Epoch 16/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6920 - val_loss: 0.6915
# Epoch 17/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6918 - val_loss: 0.6913
# Epoch 18/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6916 - val_loss: 0.6910
# Epoch 19/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6913 - val_loss: 0.6908
# Epoch 20/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6910 - val_loss: 0.6904
# Epoch 21/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6907 - val_loss: 0.6901
# Epoch 22/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6903 - val_loss: 0.6896
# Epoch 23/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6898 - val_loss: 0.6891
# Epoch 24/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6892 - val_loss: 0.6885
# Epoch 25/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6886 - val_loss: 0.6877
# Epoch 26/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6878 - val_loss: 0.6869
# Epoch 27/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6869 - val_loss: 0.6859
# Epoch 28/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6859 - val_loss: 0.6849
# Epoch 29/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6848 - val_loss: 0.6836
# Epoch 30/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6834 - val_loss: 0.6822
# Epoch 31/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6819 - val_loss: 0.6806
# Epoch 32/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6802 - val_loss: 0.6788
# Epoch 33/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6783 - val_loss: 0.6768
# Epoch 34/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6762 - val_loss: 0.6746
# Epoch 35/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6738 - val_loss: 0.6722
# Epoch 36/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6713 - val_loss: 0.6696
# Epoch 37/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6685 - val_loss: 0.6668
# Epoch 38/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6655 - val_loss: 0.6639
# Epoch 39/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6624 - val_loss: 0.6608
# Epoch 40/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6591 - val_loss: 0.6576
# Epoch 41/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6557 - val_loss: 0.6543
# Epoch 42/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6521 - val_loss: 0.6510
# Epoch 43/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6485 - val_loss: 0.6476
# Epoch 44/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6449 - val_loss: 0.6442
# Epoch 45/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6412 - val_loss: 0.6408
# Epoch 46/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6376 - val_loss: 0.6374
# Epoch 47/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6340 - val_loss: 0.6342
# Epoch 48/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6305 - val_loss: 0.6310
# Epoch 49/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6271 - val_loss: 0.6280
# Epoch 50/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6239 - val_loss: 0.6251
# Epoch 51/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6207 - val_loss: 0.6224
# Epoch 52/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6178 - val_loss: 0.6198
# Epoch 53/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6151 - val_loss: 0.6173
# Epoch 54/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6125 - val_loss: 0.6151
# Epoch 55/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6101 - val_loss: 0.6130
# Epoch 56/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6078 - val_loss: 0.6110
# Epoch 57/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6057 - val_loss: 0.6092
# Epoch 58/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6037 - val_loss: 0.6074
# Epoch 59/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6018 - val_loss: 0.6058
# Epoch 60/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6000 - val_loss: 0.6043
# Epoch 61/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.5983 - val_loss: 0.6028
# Epoch 62/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5967 - val_loss: 0.6014
# Epoch 63/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5952 - val_loss: 0.6000
# Epoch 64/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5937 - val_loss: 0.5988
# Epoch 65/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5922 - val_loss: 0.5976
# Epoch 66/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.5908 - val_loss: 0.5963
# Epoch 67/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5895 - val_loss: 0.5951
# Epoch 68/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5882 - val_loss: 0.5940
# Epoch 69/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.5869 - val_loss: 0.5928
# Epoch 70/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.5856 - val_loss: 0.5918
# Epoch 71/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.5844 - val_loss: 0.5907
# Epoch 72/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5832 - val_loss: 0.5897
# Epoch 73/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5821 - val_loss: 0.5887
# Epoch 74/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.5809 - val_loss: 0.5876
# Epoch 75/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5799 - val_loss: 0.5867
# Epoch 76/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5787 - val_loss: 0.5857
# Epoch 77/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5777 - val_loss: 0.5848
# Epoch 78/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5767 - val_loss: 0.5838
# Epoch 79/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.5756 - val_loss: 0.5830
# Epoch 80/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5747 - val_loss: 0.5820
# Epoch 81/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.5737 - val_loss: 0.5813
# Epoch 82/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5727 - val_loss: 0.5804
# Epoch 83/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.5718 - val_loss: 0.5795
# Epoch 84/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5709 - val_loss: 0.5787
# Epoch 85/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5700 - val_loss: 0.5779
# Epoch 86/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.5691 - val_loss: 0.5770
# Epoch 87/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5682 - val_loss: 0.5762
# Epoch 88/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5674 - val_loss: 0.5755
# Epoch 89/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5665 - val_loss: 0.5746
# Epoch 90/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5657 - val_loss: 0.5741
# Epoch 91/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5649 - val_loss: 0.5730
# Epoch 92/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5641 - val_loss: 0.5724
# Epoch 93/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5633 - val_loss: 0.5717
# Epoch 94/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5626 - val_loss: 0.5709
# Epoch 95/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5618 - val_loss: 0.5704
# Epoch 96/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.5611 - val_loss: 0.5694
# Epoch 97/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.5604 - val_loss: 0.5690
# Epoch 98/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.5596 - val_loss: 0.5681
# Epoch 99/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5590 - val_loss: 0.5675
# Epoch 100/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5583 - val_loss: 0.5671

# %%
def plot_history(history):
    plt.figure(figsize=(15, 5))
    ax = plt.subplot(1, 2, 1)
    plt.plot(history.history["loss"])
    plt.title("Train loss")
    ax = plt.subplot(1, 2, 2)
    plt.plot(history.history["val_loss"])
    plt.title("Test loss")

plot_history(history)

# %%
sample = 4
plt.plot(decoded_stocks[sample])
plt.plot(x_test[sample])
plt.show()

# %%
ts[:training_size].shape
# Out:
# (2555, 1)
